# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv(
    'http://d396qusza40orc.cloudfront.net/statistics/lec_resources/states.csv')

# %%
df = pd.DataFrame(data)

# %%
axes = pd.plotting.scatter_matrix(data, figsize=(20, 10), diagonal='kde')
corr = data.corr().values
for i, j in zip(*plt.np.triu_indices_from(axes, k=1)):
    axes[i, j].annotate("%.3f" %corr[i,j], (0.8, 0.8), xycoords='axes fraction', ha='center', va='center')
plt.show()

# %%
df.hist(figsize=(20, 10), bins=5)
# Out:
# array([[<AxesSubplot:title={'center':'metro_res'}>,
#         <AxesSubplot:title={'center':'white'}>],
#        [<AxesSubplot:title={'center':'hs_grad'}>,
#         <AxesSubplot:title={'center':'poverty'}>],
#        [<AxesSubplot:title={'center':'female_house'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.boxplot(figsize=(20, 10), fontsize=20)
# Out:
# <AxesSubplot:>
