# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('/home/stas/Загрузки/dataset_209770_6.txt', sep=' ')

# %%
data.plot.scatter(x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>
