# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0).iloc[:, :-1]

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.kdeplot(df, fill=True);

# %%
sns.pairplot(df, diag_kind='kde');

# %%
sns.catplot(df, kind='box');
