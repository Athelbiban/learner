# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('training_log.csv')

# %%
df
# Out:
#      train  speed  accuracy record        date
# 0    r.tr.    227      1.67    NaN  2023-05-08
# 1    e.tr.    228      2.23    NaN  2023-05-08
# 2    r.tr.    236      0.99    NaN  2023-05-08
# 3    e.tr.    212      2.47    NaN  2023-05-08
# 4    r.tr.    221      1.24    NaN  2023-05-08
# ..     ...    ...       ...    ...         ...
# 164  r.tr.    216      2.61    NaN  2023-06-17
# 165  pyth.    179      1.94    NaN  2023-06-17
# 166  r.tr.    228      0.31      m  2023-06-19
# 167  e.tr.    245      1.25    NaN  2023-06-19
# 168  r.tr.    230      1.20    NaN  2023-06-19
#
# [169 rows x 5 columns]

# %%
df.hist();

# %%
df.plot();

# %%
sns.lineplot(df);
