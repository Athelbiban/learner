# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('training_log.csv')

# %% [markdown]
# перевел данные столбца `date` в формат `datetime`

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    train  speed  accuracy record       date
# 0  r.tr.    227      1.67    NaN 2023-05-08
# 1  e.tr.    228      2.23    NaN 2023-05-08
# 2  r.tr.    236      0.99    NaN 2023-05-08
# 3  e.tr.    212      2.47    NaN 2023-05-08
# 4  r.tr.    221      1.24    NaN 2023-05-08

# %% [markdown]
# общие данные по фрейму

# %%
df.describe()
# Out:
#             speed    accuracy                           date
# count  169.000000  169.000000                            169
# mean   226.869822    1.733018  2023-05-28 14:54:40.473372672
# min    129.000000    0.310000            2023-05-08 00:00:00
# 25%    223.000000    1.210000            2023-05-20 00:00:00
# 50%    230.000000    1.550000            2023-05-28 00:00:00
# 75%    238.000000    1.930000            2023-06-06 00:00:00
# max    260.000000   16.000000            2023-06-19 00:00:00
# std     21.243085    1.379561                            NaN

# %% [markdown]
# данные сгруппированные по видам тренировок

# %%
df.groupby('train')[['speed', 'accuracy']].describe()
# Out:
#       speed                                                             \
#       count        mean        std    min    25%    50%     75%    max
# train
# N.L.    3.0  134.666667   6.658328  129.0  131.0  133.0  137.50  142.0
# SQL     2.0  144.000000   9.899495  137.0  140.5  144.0  147.50  151.0
# e.sp.   1.0  223.000000        NaN  223.0  223.0  223.0  223.00  223.0
# e.tr.  67.0  239.104478   9.324348  212.0  232.5  239.0  246.00  260.0
# pyth.   6.0  175.833333  11.178849  155.0  174.5  179.0  181.25  187.0
# r.sp.   1.0  221.000000        NaN  221.0  221.0  221.0  221.00  221.0
# r.tr.  89.0  226.179775   6.970004  207.0  222.0  226.0  231.00  240.0
#
#       accuracy
#          count       mean       std    min      25%     50%      75%    max
# train
# N.L.       3.0   1.930000  1.184947   0.57   1.5250   2.480   2.6100   2.74
# SQL        2.0   3.575000  1.152584   2.76   3.1675   3.575   3.9825   4.39
# ...

# %%
df_rtr = df[df['train'] == 'r.tr.']
df_etr = df[df['train'] == 'e.tr.']

# %% [markdown]
# графики `r.tr.`

# %%
df_rtr.plot(x='date');

# %%
sns.lineplot(df_rtr, x='date', y='speed');

# %%
sns.lineplot(df_rtr, x='date', y='accuracy');

# %% [markdown]
# графики `e.tr.`

# %%
df_rtr.plot(x='date');

# %%
sns.lineplot(df_etr, x='date', y='speed');

# %%
sns.lineplot(df_etr, x='date', y='accuracy');

# %%
df.plot.scatter(x='date', y='train');

# %%
sns.pairplot(df_rtr, diag_kind='kde');

# %%
sns.pairplot(df_etr, diag_kind='kde');

# %% [markdown]
# общие данные фрейма

# %%
df_rtr.hist();

# %%
df_etr.hist();
