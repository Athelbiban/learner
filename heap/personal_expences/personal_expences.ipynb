# %%
import pandas as pd

# %%
df = pd.read_csv('/home/stas/Загрузки/Личные расходы 2023 - Июнь.csv')

# %%
df
# Out:
#     Unnamed: 0      Unnamed: 1               Unnamed: 2      Unnamed: 3
# 0          NaN             NaN                      NaN             NaN  \
# 1          NaN             NaN          Статья расходов  1 неделя (1-4)
# 2          NaN             NaN                      NaN             NaN
# 3          NaN         Базовые      Еда, бытовые товары             NaN
# 4          NaN             NaN  Онлайн-маркеты (не еда)             NaN
# 5          NaN             NaN     Коммунальные платежи     1 675,80 ₽
# 6          NaN             NaN             Аренда жилья    14 000,00 ₽
# 7          NaN             NaN                Транспорт             NaN
# 8          NaN             NaN           Интернет (дом)       440,00 ₽
# 9          NaN             NaN        Интернет (работа)             NaN
# 10         NaN             NaN                    Связь             NaN
# 11         NaN             NaN                 Медицина             NaN
# ...
