# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('c:/Users/VostrovSO/Downloads/2023-01.csv')

# %%
df
# Out:
#     Unnamed: 0      Unnamed: 1               Unnamed: 2      Unnamed: 3
# 0          NaN             NaN                      NaN             NaN  \
# 1          NaN             NaN          Статья расходов    1 неделя (1)
# 2          NaN             NaN                      NaN             NaN
# 3          NaN         Базовые      Еда, бытовые товары             NaN
# 4          NaN             NaN  Онлайн-маркеты (не еда)             NaN
# 5          NaN             NaN     Коммунальные платежи             NaN
# 6          NaN             NaN             Аренда жилья    13 705,83 ₽
# 7          NaN             NaN                Транспорт       185,31 ₽
# 8          NaN             NaN           Интернет (дом)             NaN
# 9          NaN             NaN        Интернет (работа)             NaN
# 10         NaN             NaN                    Связь             NaN
# 11         NaN             NaN                 Медицина             NaN
# 12         NaN             NaN                   Прочее             NaN
# 13         NaN             NaN                      NaN             NaN
# 14         NaN  Дополнительные                 Сигареты             NaN
# 15         NaN             NaN     Хобби, игры, проекты             NaN
# 16         NaN             NaN       Кино, вино, домино             NaN
# 17         NaN             NaN   Оздоровление и красота             NaN
# 18         NaN             NaN                   Одежда             NaN
# 19         NaN             NaN          Бытовая техника             NaN
# 20         NaN             NaN              Путешествия             NaN
# 21         NaN             NaN                  Подарки             NaN
# 22         NaN             NaN                   Прочее             NaN
# 23         NaN            Итог                      NaN    13 891,14 ₽
#
#         Unnamed: 4       Unnamed: 5        Unnamed: 6        Unnamed: 7
# 0              NaN              NaN               NaN               NaN  \
# 1   2 неделя (2-8)  3 неделя (9-15)  4 неделя (16-22)  5 неделя (23-29)
# 2              NaN              NaN               NaN               NaN
# 3              NaN      1 522,00 ₽        3 898,00 ₽        1 297,97 ₽
# 4              NaN              NaN               NaN               NaN
# 5              NaN        306,25 ₽                NaN               NaN
# 6              NaN              NaN               NaN               NaN
# 7              NaN      1 000,00 ₽                NaN               NaN
# 8        440,00 ₽               NaN               NaN               NaN
# 9              NaN              NaN               NaN               NaN
# 10             NaN              NaN               NaN         475,00 ₽
# 11             NaN              NaN               NaN               NaN
# 12             NaN              NaN               NaN               NaN
# 13             NaN              NaN               NaN               NaN
# 14             NaN      1 972,00 ₽                NaN       1 454,00 ₽
# 15             NaN              NaN               NaN               NaN
# 16             NaN              NaN               NaN               NaN
# 17     3 140,00 ₽               NaN               NaN               NaN
# 18    10 248,00 ₽               NaN               NaN               NaN
# 19             NaN              NaN               NaN               NaN
# 20             NaN              NaN               NaN               NaN
# 21             NaN      2 000,00 ₽                NaN               NaN
# 22        61,99 ₽               NaN               NaN               NaN
# 23    13 889,99 ₽       6 800,25 ₽        3 898,00 ₽        3 226,97 ₽
#
#           Unnamed: 8      Unnamed: 9
# 0                NaN             NaN
# 1   6 неделя (30-31)            Итог
# 2                NaN             NaN
# 3        1 535,00 ₽      8 252,97 ₽
# 4                NaN          -   ₽
# 5                NaN       306,25 ₽
# 6                NaN    13 705,83 ₽
# 7                NaN     1 185,31 ₽
# 8                NaN       440,00 ₽
# 9                NaN          -   ₽
# 10               NaN       475,00 ₽
# 11               NaN          -   ₽
# 12               NaN          -   ₽
# 13               NaN             NaN
# 14               NaN     3 426,00 ₽
# 15               NaN          -   ₽
# 16               NaN          -   ₽
# 17               NaN     3 140,00 ₽
# 18               NaN    10 248,00 ₽
# 19               NaN          -   ₽
# 20               NaN          -   ₽
# 21               NaN     2 000,00 ₽
# 22               NaN        61,99 ₽
# 23       1 535,00 ₽     43 241,35 ₽

# %%
df.replace('  -   ₽ ', np.nan, inplace=True)

# %%
df.dropna(how='all', inplace=True)

# %%
df.dropna(how='all', axis=1, inplace=True)

# %%
df.columns = df.iloc[0]

# %%
df.drop(1, axis=0, inplace=True)

# %%
df
# Out:
# 1              NaN          Статья расходов    1 неделя (1)  2 неделя (2-8)
# 3          Базовые      Еда, бытовые товары             NaN             NaN  \
# 4              NaN  Онлайн-маркеты (не еда)             NaN             NaN
# 5              NaN     Коммунальные платежи             NaN             NaN
# 6              NaN             Аренда жилья    13 705,83 ₽              NaN
# 7              NaN                Транспорт       185,31 ₽              NaN
# 8              NaN           Интернет (дом)             NaN       440,00 ₽
# 9              NaN        Интернет (работа)             NaN             NaN
# 10             NaN                    Связь             NaN             NaN
# 11             NaN                 Медицина             NaN             NaN
# 12             NaN                   Прочее             NaN             NaN
# 14  Дополнительные                 Сигареты             NaN             NaN
# 15             NaN     Хобби, игры, проекты             NaN             NaN
# 16             NaN       Кино, вино, домино             NaN             NaN
# 17             NaN   Оздоровление и красота             NaN     3 140,00 ₽
# 18             NaN                   Одежда             NaN    10 248,00 ₽
# 19             NaN          Бытовая техника             NaN             NaN
# 20             NaN              Путешествия             NaN             NaN
# 21             NaN                  Подарки             NaN             NaN
# 22             NaN                   Прочее             NaN        61,99 ₽
# 23            Итог                      NaN    13 891,14 ₽     13 889,99 ₽
#
# 1  3 неделя (9-15) 4 неделя (16-22) 5 неделя (23-29) 6 неделя (30-31)
# 3      1 522,00 ₽       3 898,00 ₽       1 297,97 ₽       1 535,00 ₽   \
# 4              NaN              NaN              NaN              NaN
# 5        306,25 ₽               NaN              NaN              NaN
# 6              NaN              NaN              NaN              NaN
# 7      1 000,00 ₽               NaN              NaN              NaN
# 8              NaN              NaN              NaN              NaN
# 9              NaN              NaN              NaN              NaN
# 10             NaN              NaN        475,00 ₽               NaN
# 11             NaN              NaN              NaN              NaN
# 12             NaN              NaN              NaN              NaN
# 14     1 972,00 ₽               NaN      1 454,00 ₽               NaN
# 15             NaN              NaN              NaN              NaN
# 16             NaN              NaN              NaN              NaN
# 17             NaN              NaN              NaN              NaN
# 18             NaN              NaN              NaN              NaN
# 19             NaN              NaN              NaN              NaN
# 20             NaN              NaN              NaN              NaN
# 21     2 000,00 ₽               NaN              NaN              NaN
# 22             NaN              NaN              NaN              NaN
# 23     6 800,25 ₽       3 898,00 ₽       3 226,97 ₽       1 535,00 ₽
#
# 1             Итог
# 3      8 252,97 ₽
# 4              NaN
# 5        306,25 ₽
# 6     13 705,83 ₽
# 7      1 185,31 ₽
# 8        440,00 ₽
# 9              NaN
# 10       475,00 ₽
# 11             NaN
# 12             NaN
# 14     3 426,00 ₽
# 15             NaN
# 16             NaN
# 17     3 140,00 ₽
# 18    10 248,00 ₽
# 19             NaN
# 20             NaN
# 21     2 000,00 ₽
# 22        61,99 ₽
# 23    43 241,35 ₽
