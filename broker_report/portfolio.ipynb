# %%
import pandas as pd

# %%
portfolio = pd.read_csv('portfolio_main.csv')\
        .rename(columns={'Unnamed: 0': 'Название'})\
        .dropna(axis=0)\
        .set_index('Название')

# %%
benchmark = {
    'SBMX': 10,
    'RU000A101FA1': 20,
    'SBER': 15,
    'MTSS': 10,
    'GAZP': 8,
    'LKOH': 10,
    'MGNT': 9,
    'YNDX': 3,
    'CHMF': 5,
    'AFKS': 5,
    'IRAO': 5
}

# %%
portfolio.loc['RU000A101FA1', 'Котировки'] = portfolio.loc['RU000A101FA1', 'Котировки'] / 100 * 1000
portfolio['Текущая цена'] = portfolio['Котировки'] * portfolio['Количество']
portfolio['P/L'] = portfolio['Текущая цена'] - portfolio['Средняя цена'] * portfolio['Количество']
portfolio['P/L, %'] = (portfolio['Котировки'] * 100 / portfolio['Средняя цена'] - 100).round(2)
current_price_sum = (portfolio['Текущая цена'].sum()).round(2)
average_price_sum = ((portfolio['Средняя цена'] * portfolio['Количество']).sum()).round(2)
PL_sum = (portfolio['P/L'].sum()).round(2)
PL_per_sum = current_price_sum * 100 / average_price_sum - 100
portfolio['Пропорции, %'] = (portfolio['Текущая цена'] / current_price_sum * 100).round(2)
proportions_sum = (portfolio['Пропорции, %'].sum()).round(2)
portfolio['Бенчмарк, %'] = benchmark

# %%
portfolio
# Out:
#               Котировки  Количество  Средняя цена  Текущая цена      P/L
# Название
# SBMX            17.1500         830       15.7570       14234.5  1156.19  \
# RU000A101FA1   996.3400          35      987.4200       34871.9   312.20
# SBER           249.2500          40      224.6600        9970.0   983.60
# MTSS           287.5500          20      300.9000        5751.0  -267.00
# GAZP           171.4400          30      174.1700        5143.2   -81.90
# LKOH          5896.0000           1     4821.3300        5896.0  1074.67
# MGNT          5803.0000           1     4186.2600        5803.0  1616.74
# YNDX          2636.0000           1     2642.3800        2636.0    -6.38
# CHMF          1334.8000           1     1276.7500        1334.8    58.05
# AFKS            18.2300         100       17.7600        1823.0    47.00
# IRAO             4.1265         200        4.1628         825.3    -7.26
#
#               P/L, %  Пропорции, %  Бенчмарк, %
# Название
# SBMX            8.84         16.12           10
# RU000A101FA1    0.90         39.50           20
# SBER           10.95         11.29           15
# MTSS           -4.44          6.51           10
# GAZP           -1.57          5.83            8
# LKOH           22.29          6.68           10
# MGNT           38.62          6.57            9
# YNDX           -0.24          2.99            3
# CHMF            4.55          1.51            5
# AFKS            2.65          2.06            5
# IRAO           -0.87          0.93            5

# %%
# portfolio.loc['Итог'] = [None, None, average_price_sum, current_price_sum, PL_sum, PL_per_sum, proportions_sum]

# %%
portfolio['Разница, %'] = (portfolio['Пропорции, %'] * 100 / portfolio['Бенчмарк, %'] - 100).round(2)

# %%
portfolio
# Out:
#               Котировки  Количество  Средняя цена  Текущая цена      P/L
# Название
# SBMX            17.1500         830       15.7570       14234.5  1156.19  \
# RU000A101FA1   996.3400          35      987.4200       34871.9   312.20
# SBER           249.2500          40      224.6600        9970.0   983.60
# MTSS           287.5500          20      300.9000        5751.0  -267.00
# GAZP           171.4400          30      174.1700        5143.2   -81.90
# LKOH          5896.0000           1     4821.3300        5896.0  1074.67
# MGNT          5803.0000           1     4186.2600        5803.0  1616.74
# YNDX          2636.0000           1     2642.3800        2636.0    -6.38
# CHMF          1334.8000           1     1276.7500        1334.8    58.05
# AFKS            18.2300         100       17.7600        1823.0    47.00
# IRAO             4.1265         200        4.1628         825.3    -7.26
#
#               P/L, %  Пропорции, %  Бенчмарк, %  Разница, %
# Название
# SBMX            8.84         16.12           10       61.20
# RU000A101FA1    0.90         39.50           20       97.50
# SBER           10.95         11.29           15      -24.73
# MTSS           -4.44          6.51           10      -34.90
# GAZP           -1.57          5.83            8      -27.12
# LKOH           22.29          6.68           10      -33.20
# MGNT           38.62          6.57            9      -27.00
# YNDX           -0.24          2.99            3       -0.33
# CHMF            4.55          1.51            5      -69.80
# AFKS            2.65          2.06            5      -58.80
# IRAO           -0.87          0.93            5      -81.40

# %%
portfolio['Бенчмарк, %'].sum()
# Out:
# 100
